# %%
import utils

# %%
images, y_target, target_names, file_names = utils.pre_process()

# %%
print(images.shape)
print(y_target.shape)
print(target_names)
print(file_names)
# Out:
# (12751, 350, 350)
# (12751, 8)
# ['anger' 'contempt' 'disgust' 'fear' 'happiness' 'neutral' 'sadness'
#  'surprise']
# ['Aaron_Eckhart_0001.jpg' 'Aaron_Guiel_0001.jpg'
#  'Aaron_Patterson_0001.jpg' ... 'Zumrati_Juma_0001.jpg'
#  'Zurab_Tsereteli_0001.jpg' 'Zydrunas_Ilgauskas_0001.jpg']

# %%
import matplotlib.pyplot as plt 
plt.imshow(images[0], cmap='gray')

# %%
import cv2
img_resized = cv2.resize(images[0], (100,100))
plt.imshow(img_resized, cmap='gray')

# %%
imgs_resized = []
for i in range(len(images)):
    imgs_resized.append(cv2.resize(images[i], (70, 70)))

# %%
import numpy as np
imgs_resized_nd = np.array(imgs_resized)

# %%
plt.imshow(imgs_resized_nd[0], cmap='gray')

# %%
import h5py
# file = h5py.File('h5/images2.h5', 'w')
# dataset = file.create_dataset('images', np.shape(imgs_resized_nd), data=imgs_resized_nd)
# output = file.create_dataset('target', np.shape(y_target), data=y_target)
# file.close()
